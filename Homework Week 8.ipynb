# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Building the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer=SGD(learning_rate=0.002, momentum=0.8),
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Data preprocessing and augmentation
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)

# Load images using flow_from_directory
train_generator = train_datagen.flow_from_directory(
    'S:/ML Course/Homework Week 8/train',  # Replace with your train directory path
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    'S:/ML Course/Homework Week 8/test',  # Replace with your test directory path
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary')

# Training the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)

train_datagen_augmented = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator_augmented = train_datagen_augmented.flow_from_directory(
    'S:/ML Course/Homework Week 8/train',  # Replace with your train directory path
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary')

augmented_history = model.fit(
    train_generator_augmented,
    epochs=10,  # Additional 10 epochs
    validation_data=test_generator
)

# For Question 5: Mean of Test Loss with Augmentations
mean_test_loss_augmented = np.mean(augmented_history.history['val_loss'])

# For Question 6: Average Test Accuracy for the Last 5 Epochs
avg_test_accuracy_last_5 = np.mean(augmented_history.history['val_accuracy'][-5:])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 175232)            0
#
#  dense_8 (Dense)             (None, 64)                11214912
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 11215873 (42.79 MB)
# Trainable params: 11215873 (42.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Found 3677 images belonging to 2 classes.
# Found 918 images belonging to 2 classes.
# Epoch 1/10
# 184/184 [==============================] - 31s 164ms/step - loss: 0.6647 - accuracy: 0.6018 - val_loss: 0.5992 - val_accuracy: 0.6928
# Epoch 2/10
# 184/184 [==============================] - 30s 163ms/step - loss: 0.5936 - accuracy: 0.6810 - val_loss: 0.5778 - val_accuracy: 0.6972
# Epoch 3/10
# 184/184 [==============================] - 29s 159ms/step - loss: 0.5463 - accuracy: 0.7278 - val_loss: 0.5667 - val_accuracy: 0.6983
# Epoch 4/10
# 184/184 [==============================] - 30s 163ms/step - loss: 0.5158 - accuracy: 0.7536 - val_loss: 0.5179 - val_accuracy: 0.7516
# Epoch 5/10
# 184/184 [==============================] - 37s 199ms/step - loss: 0.4945 - accuracy: 0.7721 - val_loss: 0.5252 - val_accuracy: 0.7560
# Epoch 6/10
# 184/184 [==============================] - 39s 212ms/step - loss: 0.4583 - accuracy: 0.7958 - val_loss: 0.5590 - val_accuracy: 0.7092
# Epoch 7/10
# 184/184 [==============================] - 35s 189ms/step - loss: 0.4434 - accuracy: 0.7982 - val_loss: 0.5038 - val_accuracy: 0.7560
# Epoch 8/10
# 184/184 [==============================] - 37s 200ms/step - loss: 0.4194 - accuracy: 0.8115 - val_loss: 0.4912 - val_accuracy: 0.7778
# Epoch 9/10
# 184/184 [==============================] - 47s 254ms/step - loss: 0.3890 - accuracy: 0.8308 - val_loss: 0.4962 - val_accuracy: 0.7516
# Epoch 10/10
# 184/184 [==============================] - 68s 368ms/step - loss: 0.3637 - accuracy: 0.8431 - val_loss: 0.4944 - val_accuracy: 0.7712
# Found 3677 images belonging to 2 classes.
# Epoch 1/10
# 184/184 [==============================] - 47s 257ms/step - loss: 0.4990 - accuracy: 0.7596 - val_loss: 0.5104 - val_accuracy: 0.7571
# Epoch 2/10
# 184/184 [==============================] - 39s 212ms/step - loss: 0.4896 - accuracy: 0.7732 - val_loss: 0.5161 - val_accuracy: 0.7712
# Epoch 3/10
# 184/184 [==============================] - 39s 211ms/step - loss: 0.4861 - accuracy: 0.7696 - val_loss: 0.5194 - val_accuracy: 0.7495
# Epoch 4/10
# 184/184 [==============================] - 39s 211ms/step - loss: 0.4743 - accuracy: 0.7754 - val_loss: 0.4658 - val_accuracy: 0.7734
# Epoch 5/10
# 184/184 [==============================] - 39s 212ms/step - loss: 0.4641 - accuracy: 0.7805 - val_loss: 0.5249 - val_accuracy: 0.7582
# Epoch 6/10
# 184/184 [==============================] - 39s 211ms/step - loss: 0.4610 - accuracy: 0.7857 - val_loss: 0.4708 - val_accuracy: 0.7723
# Epoch 7/10
# 184/184 [==============================] - 39s 214ms/step - loss: 0.4587 - accuracy: 0.7884 - val_loss: 0.5414 - val_accuracy: 0.7614
# Epoch 8/10
# 184/184 [==============================] - 39s 211ms/step - loss: 0.4602 - accuracy: 0.7865 - val_loss: 0.4875 - val_accuracy: 0.7702
# Epoch 9/10
# 184/184 [==============================] - 39s 214ms/step - loss: 0.4491 - accuracy: 0.7936 - val_loss: 0.4688 - val_accuracy: 0.7876
# Epoch 10/10
# 184/184 [==============================] - 39s 211ms/step - loss: 0.4550 - accuracy: 0.7884 - val_loss: 0.4673 - val_accuracy: 0.7832

# %%
# Print the median training accuracy
median_training_accuracy = np.median(history.history['accuracy'])
print("Median Training Accuracy:", median_training_accuracy)

# Print the standard deviation of training loss
std_training_loss = np.std(history.history['loss'])
print("Standard Deviation of Training Loss:", std_training_loss)

# Assuming 'augmented_history' is from the continued training with data augmentation
# Print the mean of test loss with augmentations
mean_test_loss_augmented = np.mean(augmented_history.history['val_loss'])
print("Mean Test Loss with Augmentation:", mean_test_loss_augmented)

# Print the average test accuracy for the last 5 epochs with augmentations
avg_test_accuracy_last_5 = np.mean(augmented_history.history['val_accuracy'][-5:])
print("Average Test Accuracy for the Last 5 Epochs with Augmentation:", avg_test_accuracy_last_5)
# Out:
# Median Training Accuracy: 0.7839271128177643
# Standard Deviation of Training Loss: 0.08909810474225445
# Mean Test Loss with Augmentation: 0.49724459946155547
# Average Test Accuracy for the Last 5 Epochs with Augmentation: 0.7749455332756042
